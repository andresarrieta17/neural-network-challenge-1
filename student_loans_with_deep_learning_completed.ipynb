# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"]

# Display a sample of y
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1594    0
# 1595    1
# 1596    1
# 1597    0
# 1598    1
# Name: credit_ranking, Length: 1599, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop('credit_ranking', axis=1)

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
X_scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
num_features = X_train_scaled.shape[1]

# Review the number of features
print("Number of input features:", num_features)
# Out:
# Number of input features: 11

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_1 = 6

# Define the number of hidden nodes for the second hidden layer
hidden_nodes_2 = 3

# Define the number of neurons in the output layer
output_nodes = 1

# %%
# Create the Sequential model instance
model = tf.keras.models.Sequential()

# Add the first hidden layer
model.add(tf.keras.layers.Dense(hidden_nodes_1, activation='relu', input_shape=(num_features,)))

# Add the second hidden layer
model.add(tf.keras.layers.Dense(hidden_nodes_2, activation='relu'))

# Add the output layer to the model specifying the number of output neurons and activation function
model.add(tf.keras.layers.Dense(output_nodes, activation='sigmoid'))

# %%
# Display the Sequential model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 6)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 3)              │            21 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 97 (388.00 B)
#  Trainable params: 97 (388.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model = model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5206 - loss: 0.7416
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5986 - loss: 0.7141
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6132 - loss: 0.7025
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6452 - loss: 0.6832
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6821 - loss: 0.6671
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6923 - loss: 0.6559
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7045 - loss: 0.6495
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7205 - loss: 0.6334
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7408 - loss: 0.6176
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7384 - loss: 0.6129
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7416 - loss: 0.6063
# Epoch 12/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test,verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 - 0s - 17ms/step - accuracy: 0.7500 - loss: 0.5133
# Loss: 0.5132864713668823, Accuracy: 0.75

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.
#
# > Add blockquote

# %%
# Set the model's file path
file_path = Path("student_loans.keras")


# Export your model to a keras file
model.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Load the model to a new object
new_model = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = model.predict(X_test_scaled,verbose=2)

# Display a sample of the predictions
predictions
# Out:
# 13/13 - 0s - 9ms/step
# array([[0.5736364 ],
#        [0.41443774],
#        [0.9193222 ],
#        [0.7291844 ],
#        [0.96769637],
#        [0.79086536],
#        [0.90535665],
#        [0.06335363],
#        [0.8390278 ],
#        [0.3178115 ],
#        [0.9251141 ],
#        [0.2437319 ],
#        [0.49888635],
#        [0.9212902 ],
#        [0.55164254],
#        [0.41785327],
#        [0.91809434],
#        [0.2968575 ],
#        [0.72490233],
#        [0.36058116],
#        [0.5394688 ],
#        [0.79273736],
#        [0.29772165],
#        [0.7312981 ],
#        [0.3579628 ],
#        [0.94749224],
#        [0.6644131 ],
#        [0.8072262 ],
#        [0.26132208],
#        [0.1423162 ],
#        [0.76656294],
#        [0.8858135 ],
#        [0.2918425 ],
#        [0.89512175],
#        [0.17920205],
#        [0.57921696],
#        [0.3021749 ],
#        [0.34610027],
#        [0.9248692 ],
#        [0.1817828 ],
#        [0.90891415],
#        [0.08365379],
# ...

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=["predictions"], data=predictions)
predictions_df["predictions"] = round(predictions_df["predictions"],0)
predictions_df
# Out:
#      predictions
# 0            1.0
# 1            0.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 395          1.0
# 396          0.0
# 397          1.0
# 398          0.0
# 399          1.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df["predictions"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.78      0.74       188
#            1       0.79      0.73      0.75       212
#
#     accuracy                           0.75       400
#    macro avg       0.75      0.75      0.75       400
# weighted avg       0.75      0.75      0.75       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# When using this information in a neural network model, you would collect and organize the data into features that the model can learn from and a target that it is trying to predict. For example, you would compile student details such as demographics, academic background, and financial history into numerical or encoded features that represent each student's profile. This data forms the input layer of your neural network, where each feature provides a piece of the overall picture.
#
# Loan product details like interest rates, repayment terms, fees, and borrowing limits also need to be represented in a way that the model can understand. These could be used as additional inputs or as part of the labeling process if the recommendation is based on historical loan performance or student outcomes. Essentially, the model learns how these loan attributes interact with the student profile features to determine which loan option might be most suitable.
#
# Behavioral data, such as how students have previously interacted with loan options, can be incorporated to refine the model’s ability to predict what loan options will be most attractive or beneficial to a given student profile. This data can help the network understand the relationship between student behavior and successful loan outcomes, allowing it to fine-tune recommendations.
#
# By aggregating this diverse information into a structured format, you transform real-world details into a dataset with numerical inputs (features) and corresponding outputs (such as loan approval or satisfaction ratings). The neural network then adjusts its weights during training to establish the best mapping between the student's profile and the recommended loan options. This process enables the model to suggest personalized, appropriate student loan options based on a comprehensive view of both student characteristics and loan product specifics.
#
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# Based on the data I'm using, which includes features like payment_history, location_parameter, stem_degree_score, gpa_ranking, alumni_success, study_major_code, time_to_completion, finance_workshop_score, cohort_ranking, total_loan_score, financial_aid_score, and credit_ranking, I would use a content-based filtering approach.
#
# This is because the data I collect consists of intrinsic attributes that describe each student's profile. These features give detailed insights into a student's financial behavior, academic performance, and overall risk level. With content-based filtering, I can match the characteristics of each student—derived from these features—with the specific attributes of different student loan options. The process focuses on the content of the profiles rather than relying on user interactions or the behaviors of others.
#
# Since the features are numerical or encoded values representing key aspects of a student's financial and academic background, they provide a solid basis for a neural network to learn patterns and similarities. This makes my model capable of recommending loan options that are most likely to suit each student's needs, based on the content of their individual data.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.
#
# One challenge I would take into consideration is ensuring fairness and mitigating bias in the recommendations. In the student loan context, it is critical that the system does not inadvertently disadvantage certain groups based on their demographics or historical financial data. For instance, if the model learns from biased historical data, it might recommend less favorable loan options to students from underserved communities or those with lower credit scores, perpetuating existing inequities. Addressing this challenge involves carefully curating training data, applying fairness-aware machine learning techniques, and continuously monitoring the system's outputs to ensure that recommendations are equitable and justifiable.
#
# A second challenge is dealing with data quality and completeness. The success of a recommendation system relies heavily on having accurate and comprehensive information about a student's financial and academic background, as well as details of the available loan products. In the real world, data can often be incomplete, noisy, or outdated. This can lead to poor recommendations if the model is not robust against these issues. Therefore, I would need to implement rigorous data validation and cleaning processes, and possibly work with data imputation methods, to ensure that the neural network receives the highest quality inputs. Such efforts would help maintain the reliability and usefulness of the recommendations over time.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
